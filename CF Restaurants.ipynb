# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import timeit
from sklearn.preprocessing import MinMaxScaler
from plotly.offline import init_notebook_mode, plot, iplot
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import NormalPredictor
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import BaselineOnly
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
from surprise.accuracy import rmse
from surprise import accuracy
from surprise.model_selection import train_test_split

# %% [markdown]
# # Restaurants in SF - Collaborative Filtering Model with Surprise Package

# %% [markdown]
# Henrieke Baunack,
# Melvin Ang, 5 March 2020, 290X

# %%
df = pd.read_csv("newRestaurants.csv")
df.head(10)
df
# Out:
#              User_Name  Dragon Beaux, San Francisco  \
# 0          milkdemcows                          4.0
# 1          Frank-in-SF                          4.0
# 2              Chris F                          3.0
# 3          oregonpoppa                          5.0
# 4      yvonnechang2019                          5.0
# ...                ...                          ...
# 20719           Lynn A                          NaN
# 20720         Ozarkatv                          NaN
# 20721          Hansen5                          NaN
# 20722          Gigi318                          NaN
# 20723     Alpine_CAJim                          NaN
#
#        Seven Hills, San Francisco  Acquerello, San Francisco  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 20719                         NaN                        NaN
# 20720                         NaN                        NaN
# 20721                         NaN                        NaN
# 20722                         NaN                        NaN
# 20723                         NaN                        NaN
#
#        Betty Lou's Seafood and Grill, San Francisco  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 20719                                           NaN
# 20720                                           NaN
# 20721                                           NaN
# 20722                                           NaN
# 20723                                           NaN
#
#        Sweet Maple, San Francisco  Ristorante Franchino, San Francisco  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             3.0                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# ...                           ...                                  ...
# 20719                         NaN                                  NaN
# 20720                         NaN                                  NaN
# 20721                         NaN                                  NaN
# 20722                         NaN                                  NaN
# 20723                         NaN                                  NaN
#
#        Harborview Restaurant & Bar, San Francisco  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 20719                                         NaN
# 20720                                         NaN
# 20721                                         NaN
# 20722                                         NaN
# 20723                                         NaN
#
#        Nob Hill Cafe, San Francisco  Piccolo Forno, San Francisco  ...  \
# 0                               NaN                           NaN  ...
# 1                               NaN                           NaN  ...
# 2                               NaN                           NaN  ...
# 3                               NaN                           NaN  ...
# 4                               NaN                           NaN  ...
# ...                             ...                           ...  ...
# 20719                           NaN                           NaN  ...
# 20720                           NaN                           NaN  ...
# 20721                           NaN                           NaN  ...
# 20722                           NaN                           NaN  ...
# 20723                           NaN                           NaN  ...
#
#        Burma Superstar Restaurant, San Francisco  \
# 0                                            NaN
# 1                                            NaN
# 2                                            3.0
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 20719                                        NaN
# 20720                                        NaN
# 20721                                        NaN
# 20722                                        NaN
# 20723                                        NaN
#
#        L'ardoise Bistro, San Francisco  La Ciccia, San Francisco  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 20719                              NaN                       NaN
# 20720                              NaN                       NaN
# 20721                              NaN                       NaN
# 20722                              NaN                       NaN
# 20723                              NaN                       NaN
#
#        New Thai Elephant, San Francisco  E Tutto Qua, San Francisco  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 20719                               NaN                         NaN
# 20720                               NaN                         NaN
# 20721                               NaN                         NaN
# 20722                               NaN                         NaN
# 20723                               NaN                         NaN
#
#        Pacific Cafe, San Francisco  Kokkari Estiatorio, San Francisco  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 20719                          NaN                                NaN
# 20720                          NaN                                NaN
# 20721                          NaN                                NaN
# 20722                          NaN                                NaN
# 20723                          NaN                                NaN
#
#        Eight Am, San Francisco  Jeanne D'Arc Restaurant, San Francisco  \
# 0                          NaN                                     NaN
# 1                          NaN                                     NaN
# 2                          NaN                                     NaN
# 3                          NaN                                     NaN
# 4                          NaN                                     NaN
# ...                        ...                                     ...
# 20719                      NaN                                     NaN
# 20720                      NaN                                     NaN
# 20721                      NaN                                     NaN
# 20722                      NaN                                     NaN
# 20723                      NaN                                     NaN
#
#        Pier Market Seafood Restaurant, San Francisco
# 0                                                4.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 20719                                            4.0
# 20720                                            2.0
# 20721                                            5.0
# 20722                                            4.0
# 20723                                            5.0
#
# [20724 rows x 38 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#              User_Name  Dragon Beaux, San Francisco  \
# 0          milkdemcows                          4.0
# 1          Frank-in-SF                          4.0
# 2              Chris F                          3.0
# 3          oregonpoppa                          5.0
# 4      yvonnechang2019                          5.0
# ...                ...                          ...
# 20719           Lynn A                          NaN
# 20720         Ozarkatv                          NaN
# 20721          Hansen5                          NaN
# 20722          Gigi318                          NaN
# 20723     Alpine_CAJim                          NaN
#
#        Seven Hills, San Francisco  Acquerello, San Francisco  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 20719                         NaN                        NaN
# 20720                         NaN                        NaN
# 20721                         NaN                        NaN
# 20722                         NaN                        NaN
# 20723                         NaN                        NaN
#
#        Betty Lou's Seafood and Grill, San Francisco  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 20719                                           NaN
# 20720                                           NaN
# 20721                                           NaN
# 20722                                           NaN
# 20723                                           NaN
#
#        Sweet Maple, San Francisco  Ristorante Franchino, San Francisco  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             3.0                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# ...                           ...                                  ...
# 20719                         NaN                                  NaN
# 20720                         NaN                                  NaN
# 20721                         NaN                                  NaN
# 20722                         NaN                                  NaN
# 20723                         NaN                                  NaN
#
#        Harborview Restaurant & Bar, San Francisco  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 20719                                         NaN
# 20720                                         NaN
# 20721                                         NaN
# 20722                                         NaN
# 20723                                         NaN
#
#        Nob Hill Cafe, San Francisco  Piccolo Forno, San Francisco  ...  \
# 0                               NaN                           NaN  ...
# 1                               NaN                           NaN  ...
# 2                               NaN                           NaN  ...
# 3                               NaN                           NaN  ...
# 4                               NaN                           NaN  ...
# ...                             ...                           ...  ...
# 20719                           NaN                           NaN  ...
# 20720                           NaN                           NaN  ...
# 20721                           NaN                           NaN  ...
# 20722                           NaN                           NaN  ...
# 20723                           NaN                           NaN  ...
#
#        Burma Superstar Restaurant, San Francisco  \
# 0                                            NaN
# 1                                            NaN
# 2                                            3.0
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 20719                                        NaN
# 20720                                        NaN
# 20721                                        NaN
# 20722                                        NaN
# 20723                                        NaN
#
#        L'ardoise Bistro, San Francisco  La Ciccia, San Francisco  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2                                  NaN                       NaN
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
# ...                                ...                       ...
# 20719                              NaN                       NaN
# 20720                              NaN                       NaN
# 20721                              NaN                       NaN
# 20722                              NaN                       NaN
# 20723                              NaN                       NaN
#
#        New Thai Elephant, San Francisco  E Tutto Qua, San Francisco  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 20719                               NaN                         NaN
# 20720                               NaN                         NaN
# 20721                               NaN                         NaN
# 20722                               NaN                         NaN
# 20723                               NaN                         NaN
#
#        Pacific Cafe, San Francisco  Kokkari Estiatorio, San Francisco  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 20719                          NaN                                NaN
# 20720                          NaN                                NaN
# 20721                          NaN                                NaN
# 20722                          NaN                                NaN
# 20723                          NaN                                NaN
#
#        Eight Am, San Francisco  Jeanne D'Arc Restaurant, San Francisco  \
# 0                          NaN                                     NaN
# 1                          NaN                                     NaN
# 2                          NaN                                     NaN
# 3                          NaN                                     NaN
# 4                          NaN                                     NaN
# ...                        ...                                     ...
# 20719                      NaN                                     NaN
# 20720                      NaN                                     NaN
# 20721                      NaN                                     NaN
# 20722                      NaN                                     NaN
# 20723                      NaN                                     NaN
#
#        Pier Market Seafood Restaurant, San Francisco
# 0                                                4.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 20719                                            4.0
# 20720                                            2.0
# 20721                                            5.0
# 20722                                            4.0
# 20723                                            5.0
#
# [20014 rows x 38 columns]

# %%
#df = df.iloc[:, 0:30]
number_elements = df.size
number_nulls_nas = df.isna().sum().sum()
sparsity = number_nulls_nas/number_elements
sparsity
# Out:
# 0.9437288634797747

# %%
sum(df.count(axis='columns',  numeric_only=True) > 1)
# Out:
# 2039

# %%
df.drop(df[df.count(axis='columns',  numeric_only=True) < 2].index, inplace=True)
df
# Out:
# /Users/henriekebaunack/anaconda3/envs/data-x/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  User_Name  Dragon Beaux, San Francisco  \
# 0              milkdemcows                          4.0
# 2                  Chris F                          3.0
# 5      TravelingAuntMarian                          5.0
# 7        UnrepentantFoodie                          5.0
# 8        UnrepentantFoodie                          2.0
# ...                    ...                          ...
# 18550                Ron C                          NaN
# 18569               Erik L                          NaN
# 18814              James W                          NaN
# 18815              James W                          NaN
# 18831             DoraF406                          NaN
#
#        Seven Hills, San Francisco  Acquerello, San Francisco  \
# 0                             NaN                        NaN
# 2                             NaN                        NaN
# 5                             NaN                        NaN
# 7                             NaN                        NaN
# 8                             NaN                        NaN
# ...                           ...                        ...
# 18550                         NaN                        NaN
# 18569                         NaN                        NaN
# 18814                         NaN                        NaN
# 18815                         NaN                        NaN
# 18831                         NaN                        NaN
#
#        Betty Lou's Seafood and Grill, San Francisco  \
# 0                                               NaN
# 2                                               NaN
# 5                                               NaN
# 7                                               NaN
# 8                                               NaN
# ...                                             ...
# 18550                                           NaN
# 18569                                           NaN
# 18814                                           NaN
# 18815                                           NaN
# 18831                                           NaN
#
#        Sweet Maple, San Francisco  Ristorante Franchino, San Francisco  \
# 0                             NaN                                  NaN
# 2                             3.0                                  NaN
# 5                             NaN                                  NaN
# 7                             NaN                                  NaN
# 8                             NaN                                  NaN
# ...                           ...                                  ...
# 18550                         NaN                                  NaN
# 18569                         NaN                                  NaN
# 18814                         NaN                                  NaN
# 18815                         NaN                                  NaN
# 18831                         NaN                                  NaN
#
#        Harborview Restaurant & Bar, San Francisco  \
# 0                                             NaN
# 2                                             NaN
# 5                                             NaN
# 7                                             NaN
# 8                                             NaN
# ...                                           ...
# 18550                                         NaN
# 18569                                         NaN
# 18814                                         NaN
# 18815                                         NaN
# 18831                                         NaN
#
#        Nob Hill Cafe, San Francisco  Piccolo Forno, San Francisco  ...  \
# 0                               NaN                           NaN  ...
# 2                               NaN                           NaN  ...
# 5                               4.0                           NaN  ...
# 7                               NaN                           NaN  ...
# 8                               NaN                           NaN  ...
# ...                             ...                           ...  ...
# 18550                           NaN                           NaN  ...
# 18569                           NaN                           NaN  ...
# 18814                           NaN                           NaN  ...
# 18815                           NaN                           NaN  ...
# 18831                           NaN                           NaN  ...
#
#        Burma Superstar Restaurant, San Francisco  \
# 0                                            NaN
# 2                                            3.0
# 5                                            NaN
# 7                                            NaN
# 8                                            NaN
# ...                                          ...
# 18550                                        NaN
# 18569                                        NaN
# 18814                                        NaN
# 18815                                        NaN
# 18831                                        NaN
#
#        L'ardoise Bistro, San Francisco  La Ciccia, San Francisco  \
# 0                                  NaN                       NaN
# 2                                  NaN                       NaN
# 5                                  NaN                       NaN
# 7                                  NaN                       NaN
# 8                                  NaN                       NaN
# ...                                ...                       ...
# 18550                              NaN                       NaN
# 18569                              NaN                       NaN
# 18814                              NaN                       NaN
# 18815                              NaN                       NaN
# 18831                              NaN                       NaN
#
#        New Thai Elephant, San Francisco  E Tutto Qua, San Francisco  \
# 0                                   NaN                         NaN
# 2                                   NaN                         NaN
# 5                                   NaN                         NaN
# 7                                   NaN                         NaN
# 8                                   NaN                         NaN
# ...                                 ...                         ...
# 18550                               NaN                         NaN
# 18569                               NaN                         NaN
# 18814                               NaN                         NaN
# 18815                               NaN                         NaN
# 18831                               NaN                         NaN
#
#        Pacific Cafe, San Francisco  Kokkari Estiatorio, San Francisco  \
# 0                              NaN                                NaN
# 2                              NaN                                NaN
# 5                              NaN                                NaN
# 7                              NaN                                NaN
# 8                              NaN                                NaN
# ...                            ...                                ...
# 18550                          NaN                                NaN
# 18569                          NaN                                NaN
# 18814                          NaN                                NaN
# 18815                          NaN                                NaN
# 18831                          NaN                                NaN
#
#        Eight Am, San Francisco  Jeanne D'Arc Restaurant, San Francisco  \
# 0                          NaN                                     NaN
# 2                          NaN                                     NaN
# 5                          NaN                                     NaN
# 7                          NaN                                     NaN
# 8                          NaN                                     NaN
# ...                        ...                                     ...
# 18550                      NaN                                     5.0
# 18569                      NaN                                     5.0
# 18814                      NaN                                     1.0
# 18815                      NaN                                     5.0
# 18831                      NaN                                     5.0
#
#        Pier Market Seafood Restaurant, San Francisco
# 0                                                4.0
# 2                                                NaN
# 5                                                NaN
# 7                                                NaN
# 8                                                NaN
# ...                                              ...
# 18550                                            5.0
# 18569                                            5.0
# 18814                                            5.0
# 18815                                            5.0
# 18831                                            4.0
#
# [2039 rows x 38 columns]

# %%
df_cropped = df
display(df_cropped)
# Out:
#                  User_Name  Dragon Beaux, San Francisco  \
# 0              milkdemcows                          4.0
# 2                  Chris F                          3.0
# 5      TravelingAuntMarian                          5.0
# 7        UnrepentantFoodie                          5.0
# 8        UnrepentantFoodie                          2.0
# ...                    ...                          ...
# 18550                Ron C                          NaN
# 18569               Erik L                          NaN
# 18814              James W                          NaN
# 18815              James W                          NaN
# 18831             DoraF406                          NaN
#
#        Seven Hills, San Francisco  Acquerello, San Francisco  \
# 0                             NaN                        NaN
# 2                             NaN                        NaN
# 5                             NaN                        NaN
# 7                             NaN                        NaN
# 8                             NaN                        NaN
# ...                           ...                        ...
# 18550                         NaN                        NaN
# 18569                         NaN                        NaN
# 18814                         NaN                        NaN
# 18815                         NaN                        NaN
# 18831                         NaN                        NaN
#
#        Betty Lou's Seafood and Grill, San Francisco  \
# 0                                               NaN
# 2                                               NaN
# 5                                               NaN
# 7                                               NaN
# 8                                               NaN
# ...                                             ...
# 18550                                           NaN
# 18569                                           NaN
# 18814                                           NaN
# 18815                                           NaN
# 18831                                           NaN
#
#        Sweet Maple, San Francisco  Ristorante Franchino, San Francisco  \
# 0                             NaN                                  NaN
# 2                             3.0                                  NaN
# 5                             NaN                                  NaN
# 7                             NaN                                  NaN
# 8                             NaN                                  NaN
# ...                           ...                                  ...
# 18550                         NaN                                  NaN
# 18569                         NaN                                  NaN
# 18814                         NaN                                  NaN
# 18815                         NaN                                  NaN
# 18831                         NaN                                  NaN
#
#        Harborview Restaurant & Bar, San Francisco  \
# 0                                             NaN
# 2                                             NaN
# 5                                             NaN
# 7                                             NaN
# 8                                             NaN
# ...                                           ...
# 18550                                         NaN
# 18569                                         NaN
# 18814                                         NaN
# 18815                                         NaN
# 18831                                         NaN
#
#        Nob Hill Cafe, San Francisco  Piccolo Forno, San Francisco  ...  \
# 0                               NaN                           NaN  ...
# 2                               NaN                           NaN  ...
# 5                               4.0                           NaN  ...
# 7                               NaN                           NaN  ...
# 8                               NaN                           NaN  ...
# ...                             ...                           ...  ...
# 18550                           NaN                           NaN  ...
# 18569                           NaN                           NaN  ...
# 18814                           NaN                           NaN  ...
# 18815                           NaN                           NaN  ...
# 18831                           NaN                           NaN  ...
#
#        Burma Superstar Restaurant, San Francisco  \
# 0                                            NaN
# 2                                            3.0
# 5                                            NaN
# 7                                            NaN
# 8                                            NaN
# ...                                          ...
# 18550                                        NaN
# 18569                                        NaN
# 18814                                        NaN
# 18815                                        NaN
# 18831                                        NaN
#
#        L'ardoise Bistro, San Francisco  La Ciccia, San Francisco  \
# 0                                  NaN                       NaN
# 2                                  NaN                       NaN
# 5                                  NaN                       NaN
# 7                                  NaN                       NaN
# 8                                  NaN                       NaN
# ...                                ...                       ...
# 18550                              NaN                       NaN
# 18569                              NaN                       NaN
# 18814                              NaN                       NaN
# 18815                              NaN                       NaN
# 18831                              NaN                       NaN
#
#        New Thai Elephant, San Francisco  E Tutto Qua, San Francisco  \
# 0                                   NaN                         NaN
# 2                                   NaN                         NaN
# 5                                   NaN                         NaN
# 7                                   NaN                         NaN
# 8                                   NaN                         NaN
# ...                                 ...                         ...
# 18550                               NaN                         NaN
# 18569                               NaN                         NaN
# 18814                               NaN                         NaN
# 18815                               NaN                         NaN
# 18831                               NaN                         NaN
#
#        Pacific Cafe, San Francisco  Kokkari Estiatorio, San Francisco  \
# 0                              NaN                                NaN
# 2                              NaN                                NaN
# 5                              NaN                                NaN
# 7                              NaN                                NaN
# 8                              NaN                                NaN
# ...                            ...                                ...
# 18550                          NaN                                NaN
# 18569                          NaN                                NaN
# 18814                          NaN                                NaN
# 18815                          NaN                                NaN
# 18831                          NaN                                NaN
#
#        Eight Am, San Francisco  Jeanne D'Arc Restaurant, San Francisco  \
# 0                          NaN                                     NaN
# 2                          NaN                                     NaN
# 5                          NaN                                     NaN
# 7                          NaN                                     NaN
# 8                          NaN                                     NaN
# ...                        ...                                     ...
# 18550                      NaN                                     5.0
# 18569                      NaN                                     5.0
# 18814                      NaN                                     1.0
# 18815                      NaN                                     5.0
# 18831                      NaN                                     5.0
#
#        Pier Market Seafood Restaurant, San Francisco
# 0                                                4.0
# 2                                                NaN
# 5                                                NaN
# 7                                                NaN
# 8                                                NaN
# ...                                              ...
# 18550                                            5.0
# 18569                                            5.0
# 18814                                            5.0
# 18815                                            5.0
# 18831                                            4.0
#
# [2039 rows x 38 columns]

# %%
sum(df_cropped.count(axis='columns',  numeric_only=True) > 5)
# Out:
# 615

# %%
df_restaurants = df_cropped.columns[1:].array
df_restaurants
# Out:
# <PandasArray>
# [              'Pacific Catch, San Francisco_x',
#            'Liholiho Yacht Club, San Francisco',
#                       'Frascati, San Francisco',
#      'Taylor Street Coffee Shop, San Francisco',
#          'Fino Bar & Ristorante, San Francisco',
#     'Pazzia Ristorante Italiano, San Francisco',
#         'El Nuevo Frutilandia, San Francisco_x',
#                        'Trestle, San Francisco',
#          'Restaurant Gary Danko, San Francisco',
#              'Ristorante Milano, San Francisco',
#                       'Za Pizza, San Francisco',
#                          'Zazie, San Francisco',
#           'Reed and Greenough, San Francisco_x',
#                      'Surisan, San Francisco_x',
#          'State Bird Provisions, San Francisco',
#      "Brenda's French Soul Food, San Francisco",
#  'Sotto Mare Oysteria & Seafood, San Francisco',
#                        'Frances, San Francisco',
#                          'SPIN San Francisco_x',
#                           'Mymy, San Francisco',
#          'Fog Harbor Fish House, San Francisco',
#                           'Nopa, San Francisco',
#                       'La Folie, San Francisco',
#               'Buena Vista Cafe, San Francisco',
#        'OSHA Thai Noodle Cafe, San Francisco_x',
#                  'Atelier Crenn, San Francisco',
#                     'Home Plate, San Francisco',
#                        'Octavia, San Francisco',
#                   'Tadich Grill, San Francisco']
# Length: 29, dtype: object

# %%
#convert to Surprise package dataframe format

df_colnames = df_cropped.columns[1:].array
df_colnames
df2 = pd.melt(df_cropped, id_vars=['User_Name'], value_vars=df_colnames, var_name='Restaurant', value_name='Rating')
df2.shape
display(df2)
# Out:
#                  User_Name                                     Restaurant  \
# 0              milkdemcows                    Dragon Beaux, San Francisco
# 1                  Chris F                    Dragon Beaux, San Francisco
# 2      TravelingAuntMarian                    Dragon Beaux, San Francisco
# 3        UnrepentantFoodie                    Dragon Beaux, San Francisco
# 4        UnrepentantFoodie                    Dragon Beaux, San Francisco
# ...                    ...                                            ...
# 75438                Ron C  Pier Market Seafood Restaurant, San Francisco
# 75439               Erik L  Pier Market Seafood Restaurant, San Francisco
# 75440              James W  Pier Market Seafood Restaurant, San Francisco
# 75441              James W  Pier Market Seafood Restaurant, San Francisco
# 75442             DoraF406  Pier Market Seafood Restaurant, San Francisco
#
#        Rating
# 0         4.0
# 1         3.0
# 2         5.0
# 3         5.0
# 4         2.0
# ...       ...
# 75438     5.0
# 75439     5.0
# 75440     5.0
# 75441     5.0
# 75442     4.0
#
# [75443 rows x 3 columns]

# %%
df_new = df2.drop_duplicates()

# %%
df_new
# Out:
#                  User_Name                                     Restaurant  \
# 0              milkdemcows                    Dragon Beaux, San Francisco
# 1                  Chris F                    Dragon Beaux, San Francisco
# 2      TravelingAuntMarian                    Dragon Beaux, San Francisco
# 3        UnrepentantFoodie                    Dragon Beaux, San Francisco
# 4        UnrepentantFoodie                    Dragon Beaux, San Francisco
# ...                    ...                                            ...
# 75437            Anthony D  Pier Market Seafood Restaurant, San Francisco
# 75438                Ron C  Pier Market Seafood Restaurant, San Francisco
# 75439               Erik L  Pier Market Seafood Restaurant, San Francisco
# 75440              James W  Pier Market Seafood Restaurant, San Francisco
# 75442             DoraF406  Pier Market Seafood Restaurant, San Francisco
#
#        Rating
# 0         4.0
# 1         3.0
# 2         5.0
# 3         5.0
# 4         2.0
# ...       ...
# 75437     4.0
# 75438     5.0
# 75439     5.0
# 75440     5.0
# 75442     4.0
#
# [72742 rows x 3 columns]

# %%
"""#filter to reduce dataset 
min_place_ratings = 5
filter_place = df_new['Restaurant'].value_counts() > min_place_ratings
filter_place = filter_place[filter_place].index.tolist()
#df2.groupby('Place').count()['Rating'] 

min_user_ratings = 2
filter_users = df_new.groupby('User_Name').count()['Rating'] > min_user_ratings #min 3 ratings 
filter_users = filter_users[filter_users].index.tolist()
#df2.groupby('Name').count().sort_values(by=['Rating'], ascending=False)['Rating']

df_new2 = df_new[(df_new['Restaurant'].isin(filter_place)) & (df_new['User_Name'].isin(filter_users))]
print('The original data frame shape:\t{}'.format(df_new.shape))
print('The new data frame shape:\t{}'.format(df_new2.shape))"""
# Out:
# The original data frame shape:	(45493, 3)
# The new data frame shape:	(32616, 3)

# %%
df_new = df_new.fillna(0)
df_new.shape
# Out:
# (72742, 3)

# %% [markdown]
# ## divide all ratings by 10 so the scale becomes 1-5
# #df_new["Rating"] = df_new["Rating"].div(10)
# df_new2.describe()

# %%
df_new.describe()
# Out:
#              Rating
# count  72742.000000
# mean       0.287647
# std        1.118557
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        5.000000

# %%
#initiate Surprise
reader = Reader(rating_scale=(0, 5))
Surprise_data = Dataset.load_from_df(df_new[['User_Name', 'Restaurant', 'Rating']], reader)

# %% [markdown]
# # Try Different Algorithms

# %%
#train on whole set and predict
# Retrieve the trainset.    
full_trainset = Surprise_data.build_full_trainset()

# Build an algorithm, and train it.
# Build an algorithm, and train it.
sim_options = {'name': 'cosine', # way to compute similarity matrix
               'user_based': True #Similarity based on similar users
               }
algoKNNBasic = KNNBasic(sim_options=sim_options)
algoKNNBasic.fit(full_trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoSVD = SVD()
algoSVD.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsSVD = algoSVD.fit(trainset).test(testset)
accuracy.rmse(predictionsSVD)
# Out:
# RMSE: 0.0620
# 0.06202285794985639

# %% [markdown]
# #train on whole set and predict
# # Retrieve the trainset.
# full_trainset = Surprise_data.build_full_trainset()
# sim_options = {'name': 'cosine',
#                'user_based': True #Similarity based on similar users
#                }
# algoKNNBaseline = KNNBaseline(sim_options=sim_options)
# algoKNNBaseline.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsKNNBasic = algoKNNBasic.fit(trainset).test(testset)
accuracy.rmse(predictionsKNNBasic)
# Out:
# Computing the cosine similarity matrix...
# /Users/henriekebaunack/anaconda3/envs/data-x/lib/python3.7/site-packages/surprise/prediction_algorithms/algo_base.py:248: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Done computing similarity matrix.
# RMSE: 1.1365
# 1.1365341489390712

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsKNNBaseline = algoKNNBaseline.fit(trainset).test(testset)
accuracy.rmse(predictionsKNNBaseline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-757b2666ef62> in <module>
#       2 trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#       3 #algo = BaselineOnly(bsl_options=bsl_options)
# ----> 4 predictionsKNNBaseline = algoKNNBaseline.fit(trainset).test(testset)
#       5 accuracy.rmse(predictionsKNNBaseline)
#
# NameError: name 'algoKNNBaseline' is not defined

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoBaselineOnly = BaselineOnly()
algoBaselineOnly.fit(full_trainset)
# Out:
# Estimating biases using als...

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsBaselineOnly = algoBaselineOnly.fit(trainset).test(testset)
accuracy.rmse(predictionsBaselineOnly)
# Out:
# Estimating biases using als...
# RMSE: 1.4846
# 1.4845762391657442

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoCoClustering = CoClustering()
algoCoClustering.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsCoClustering = algoCoClustering.fit(trainset).test(testset)
accuracy.rmse(predictionsCoClustering)
# Out:
# RMSE: 1.5126
# 1.512581985164737

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoNormalPredictor = NormalPredictor()
algoNormalPredictor.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsNormalPredictor = algoNormalPredictor.fit(trainset).test(testset)
accuracy.rmse(predictionsNormalPredictor)
# Out:
# RMSE: 1.8636
# 1.8636400092448973

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
sim_options = {'name': 'cosine',
               'user_based': True #Similarity based on similar users
               }
algoKNNWithMeans = KNNWithMeans(sim_options=sim_options)
algoKNNWithMeans.fit(full_trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsKNNWithMeans = algoKNNWithMeans.fit(trainset).test(testset)
accuracy.rmse(predictionsKNNWithMeans)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4360
# 1.4360302776389788

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
sim_options = {'name': 'cosine',
               'user_based': True #Similarity based on similar users
               }
algoKNNWithZScore = KNNWithZScore(sim_options=sim_options)
algoKNNWithZScore.fit(full_trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsKNNWithZScore = algoKNNWithZScore.fit(trainset).test(testset)
accuracy.rmse(predictionsKNNWithZScore)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.4394
# 1.4393954529215478

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoSVDpp = SVDpp()
algoSVDpp.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsSVDpp = algoSVDpp.fit(trainset).test(testset)
accuracy.rmse(predictionsSVDpp)
# Out:
# RMSE: 1.4821
# 1.4820760563768778

# %%
#train on whole set and predict
# Retrieve the trainset.
full_trainset = Surprise_data.build_full_trainset()
algoSlopeOne = SlopeOne()
algoSlopeOne.fit(full_trainset)

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25, random_state=100)
#algo = BaselineOnly(bsl_options=bsl_options)
predictionsSlopeOne = algoSlopeOne.fit(trainset).test(testset)
accuracy.rmse(predictionsSlopeOne)
# Out:
# RMSE: 1.5009
# 1.5009175288343197

# %% [markdown]
# # Predicting

# %%
df_new
# Out:
#                  User_Name                                     Restaurant  \
# 0              milkdemcows                    Dragon Beaux, San Francisco
# 1                  Chris F                    Dragon Beaux, San Francisco
# 2      TravelingAuntMarian                    Dragon Beaux, San Francisco
# 3        UnrepentantFoodie                    Dragon Beaux, San Francisco
# 4        UnrepentantFoodie                    Dragon Beaux, San Francisco
# ...                    ...                                            ...
# 75437            Anthony D  Pier Market Seafood Restaurant, San Francisco
# 75438                Ron C  Pier Market Seafood Restaurant, San Francisco
# 75439               Erik L  Pier Market Seafood Restaurant, San Francisco
# 75440              James W  Pier Market Seafood Restaurant, San Francisco
# 75442             DoraF406  Pier Market Seafood Restaurant, San Francisco
#
#        Rating
# 0         4.0
# 1         3.0
# 2         5.0
# 3         5.0
# 4         2.0
# ...       ...
# 75437     4.0
# 75438     5.0
# 75439     5.0
# 75440     5.0
# 75442     4.0
#
# [72742 rows x 3 columns]

# %%
df_new.drop_duplicates()
# Out:
#                  User_Name                                     Restaurant  \
# 0              milkdemcows                    Dragon Beaux, San Francisco
# 1                  Chris F                    Dragon Beaux, San Francisco
# 2      TravelingAuntMarian                    Dragon Beaux, San Francisco
# 3        UnrepentantFoodie                    Dragon Beaux, San Francisco
# 4        UnrepentantFoodie                    Dragon Beaux, San Francisco
# ...                    ...                                            ...
# 75437            Anthony D  Pier Market Seafood Restaurant, San Francisco
# 75438                Ron C  Pier Market Seafood Restaurant, San Francisco
# 75439               Erik L  Pier Market Seafood Restaurant, San Francisco
# 75440              James W  Pier Market Seafood Restaurant, San Francisco
# 75442             DoraF406  Pier Market Seafood Restaurant, San Francisco
#
#        Rating
# 0         4.0
# 1         3.0
# 2         5.0
# 3         5.0
# 4         2.0
# ...       ...
# 75437     4.0
# 75438     5.0
# 75439     5.0
# 75440     5.0
# 75442     4.0
#
# [72742 rows x 3 columns]

# %%
# converting to strings does not help
#df_new2["User_Name"] = df_new2["User_Name"].to_string()
#df_new2["Restaurant"] = df_new2["Restaurant"].to_string()

# %%
#predict 
uid = "UnrepentantFoodie" # raw user id (as in the ratings file). They are **strings**!
iid = "Dragon Beaux, San Francisco" # raw item id (restrauran in this case)
# get a prediction for specific users and items.
pred=algoKNNBasic.predict(uid, iid, r_ui=5, verbose=True) # r_ui: if you know the original rating you can put it htere to compare with the estaimation
# Out:
# user: UnrepentantFoodie item: Dragon Beaux, San Francisco r_ui = 5.00   est = 0.86   {'actual_k': 10, 'was_impossible': False}

# %%
uid = str("834tamih")
user_list = []
place_list = []
rating_list = []
for i in range(len(df_placenames)):
    iid = df_placenames[i]
    #df_estimated_ratings = pd.DataFrame(algo.predict(uid, iid, verbose=True)[3])
    user_list.append(algoKNNBasic.predict(uid, iid, verbose=True)[0])
    place_list.append(algoKNNBasic.predict(uid, iid, verbose=True)[1])
    rating_list.append(algoKNNBasic.predict(uid, iid, verbose=True)[3])
# Out:
# user: 834tamih   item: 16_Avenue_Tiled_Steps r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: 16_Avenue_Tiled_Steps r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: 16_Avenue_Tiled_Steps r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: California_Academy_of_Sciences r_ui = None   est = 0.26   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: California_Academy_of_Sciences r_ui = None   est = 0.26   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: California_Academy_of_Sciences r_ui = None   est = 0.26   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Alcatraz_Island r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Alcatraz_Island r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Alcatraz_Island r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Cars r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Cars r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Cars r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Exploratorium r_ui = None   est = 0.54   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Exploratorium r_ui = None   est = 0.54   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Exploratorium r_ui = None   est = 0.54   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or5-Golden_Gate_Bridge r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or5-Golden_Gate_Bridge r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or5-Golden_Gate_Bridge r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Golden_Gate_Park r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Golden_Gate_Park r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Golden_Gate_Park r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lands_End  r_ui = None   est = 0.93   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lands_End  r_ui = None   est = 0.93   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lands_End  r_ui = None   est = 0.93   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Oracle_Park r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Oracle_Park r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Oracle_Park r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Palace_of_Fine_Arts_Theatre r_ui = None   est = 0.43   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Palace_of_Fine_Arts_Theatre r_ui = None   est = 0.43   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Palace_of_Fine_Arts_Theatre r_ui = None   est = 0.43   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Twin_Peaks r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Twin_Peaks r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Twin_Peaks r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Walt_Disney_Family_Museum r_ui = None   est = 0.42   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Walt_Disney_Family_Museum r_ui = None   est = 0.42   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Walt_Disney_Family_Museum r_ui = None   est = 0.42   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ferry_Building_Marketplace r_ui = None   est = 0.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ferry_Building_Marketplace r_ui = None   est = 0.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ferry_Building_Marketplace r_ui = None   est = 0.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lombard_Street r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lombard_Street r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Lombard_Street r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Museum_of_Modern_Art_SFMOMA r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Museum_of_Modern_Art_SFMOMA r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Museum_of_Modern_Art_SFMOMA r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Coit_Tower r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Coit_Tower r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Coit_Tower r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Legion_of_Honor r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Legion_of_Honor r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Legion_of_Honor r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Bay r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Bay r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Bay r_ui = None   est = 0.34   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Pier_39    r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Pier_39    r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Pier_39    r_ui = None   est = 0.07   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or1395-Museum_of_Ice_Cream r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or1395-Museum_of_Ice_Cream r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: or1395-Museum_of_Ice_Cream r_ui = None   est = 0.00   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Botanical_Garden r_ui = None   est = 1.95   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Botanical_Garden r_ui = None   est = 1.95   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: San_Francisco_Botanical_Garden r_ui = None   est = 1.95   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: De_Young_Museum r_ui = None   est = 0.45   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: De_Young_Museum r_ui = None   est = 0.45   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: De_Young_Museum r_ui = None   est = 0.45   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Car_Museum r_ui = None   est = 0.35   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Car_Museum r_ui = None   est = 0.35   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Cable_Car_Museum r_ui = None   est = 0.35   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Presidio_of_San_Francisco r_ui = None   est = 3.96   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Presidio_of_San_Francisco r_ui = None   est = 3.96   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Presidio_of_San_Francisco r_ui = None   est = 3.96   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Baker_Beach r_ui = None   est = 2.97   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Baker_Beach r_ui = None   est = 2.97   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Baker_Beach r_ui = None   est = 2.97   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Angel_Island_State_Park r_ui = None   est = 2.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Angel_Island_State_Park r_ui = None   est = 2.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Angel_Island_State_Park r_ui = None   est = 2.18   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Mission_Dolores_Park r_ui = None   est = 0.31   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Mission_Dolores_Park r_ui = None   est = 0.31   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Mission_Dolores_Park r_ui = None   est = 0.31   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Fisherman_s_Wharf r_ui = None   est = 0.12   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Fisherman_s_Wharf r_ui = None   est = 0.12   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Fisherman_s_Wharf r_ui = None   est = 0.12   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Japanese_Tea_Garden r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Japanese_Tea_Garden r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Japanese_Tea_Garden r_ui = None   est = 0.50   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ghirardelli_Square r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ghirardelli_Square r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Ghirardelli_Square r_ui = None   est = 0.09   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Chinatown  r_ui = None   est = 0.20   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Chinatown  r_ui = None   est = 0.20   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Chinatown  r_ui = None   est = 0.20   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Union_Square r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Union_Square r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Union_Square r_ui = None   est = 0.27   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Painted_Ladies r_ui = None   est = 0.22   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Painted_Ladies r_ui = None   est = 0.22   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Painted_Ladies r_ui = None   est = 0.22   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Haight_Ashbury r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Haight_Ashbury r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}
# user: 834tamih   item: Haight_Ashbury r_ui = None   est = 0.52   {'actual_k': 40, 'was_impossible': False}

# %%
#Print final result table
df_estimate_result = pd.DataFrame(user_list, columns =['Name'])
df_estimate_result["Place"] = pd.DataFrame(place_list)
df_estimate_result = df_estimate_result.merge(df_new[df_new["Name"] == uid], on='Place', how='outer').drop(['Name_y'], axis=1)
df_estimate_result["Estimated Rating"] = pd.DataFrame(rating_list)
df_estimate_result = df_estimate_result.rename(columns={"Name_x": "Name"})
df_estimate_result = df_estimate_result.rename(columns={"Rating": "Original Rating"})
df_estimate_result["Absolute Error"] = abs(df_estimate_result["Original Rating"] - df_estimate_result["Estimated Rating"])
df_estimate_result.sort_values(by=['Estimated Rating'],ascending=False)
# Out:
#         Name                                      Place  Original Rating  \
# 23  834tamih                  Presidio_of_San_Francisco              5.0
# 24  834tamih                                Baker_Beach              5.0
# 25  834tamih                    Angel_Island_State_Park              5.0
# 20  834tamih             San_Francisco_Botanical_Garden              4.0
# 7   834tamih                                  Lands_End              0.0
# 4   834tamih                              Exploratorium              0.0
# 33  834tamih                             Haight_Ashbury              0.0
# 16  834tamih                            Legion_of_Honor              0.0
# 28  834tamih                        Japanese_Tea_Garden              0.0
# 14  834tamih  San_Francisco_Museum_of_Modern_Art_SFMOMA              0.0
# 21  834tamih                            De_Young_Museum              0.0
# 9   834tamih                Palace_of_Fine_Arts_Theatre              0.0
# 11  834tamih                  Walt_Disney_Family_Museum              0.0
# 22  834tamih                           Cable_Car_Museum              0.0
# 6   834tamih                           Golden_Gate_Park              0.0
# 17  834tamih                          San_Francisco_Bay              0.0
# 26  834tamih                       Mission_Dolores_Park              0.0
# 31  834tamih                               Union_Square              0.0
# 10  834tamih                                 Twin_Peaks              0.0
# 1   834tamih             California_Academy_of_Sciences              0.0
# 32  834tamih                             Painted_Ladies              0.0
# 30  834tamih                                  Chinatown              0.0
# 12  834tamih                 Ferry_Building_Marketplace              0.0
# 27  834tamih                          Fisherman_s_Wharf              0.0
# 29  834tamih                         Ghirardelli_Square              0.0
# 3   834tamih                                 Cable_Cars              0.0
# 18  834tamih                                    Pier_39              0.0
# 8   834tamih                                Oracle_Park              0.0
# 15  834tamih                                 Coit_Tower              0.0
# 2   834tamih                            Alcatraz_Island              0.0
# 5   834tamih                     or5-Golden_Gate_Bridge              0.0
# 13  834tamih                             Lombard_Street              0.0
# 19  834tamih                 or1395-Museum_of_Ice_Cream              0.0
# 0   834tamih                      16_Avenue_Tiled_Steps              0.0
#
#     Estimated Rating  Absolute Error
# 23          3.956940        1.043060
# 24          2.966907        2.033093
# 25          2.175897        2.824103
# 20          1.953024        2.046976
# 7           0.927657        0.927657
# 4           0.543513        0.543513
# 33          0.522273        0.522273
# 16          0.517162        0.517162
# 28          0.503824        0.503824
# 14          0.496313        0.496313
# 21          0.453123        0.453123
# 9           0.434534        0.434534
# 11          0.424371        0.424371
# 22          0.349508        0.349508
# 6           0.343141        0.343141
# 17          0.340818        0.340818
# 26          0.305083        0.305083
# 31          0.274148        0.274148
# 10          0.268072        0.268072
# 1           0.255891        0.255891
# 32          0.221275        0.221275
# 30          0.204662        0.204662
# 12          0.175969        0.175969
# 27          0.116834        0.116834
# 29          0.090613        0.090613
# 3           0.089396        0.089396
# 18          0.067047        0.067047
# 8           0.066872        0.066872
# 15          0.000000        0.000000
# 2           0.000000        0.000000
# 5           0.000000        0.000000
# 13          0.000000        0.000000
# 19          0.000000        0.000000
# 0           0.000000        0.000000

# %%
#train and test set to check RMSE of model
trainset, testset = train_test_split(Surprise_data, test_size=0.25)
#algo = BaselineOnly(bsl_options=bsl_options)
predictions = algo.fit(trainset).test(testset)
accuracy.rmse(predictions)
# Out:
# Computing the cosine similarity matrix...
# /Users/melvinang/anaconda3/lib/python3.7/site-packages/surprise/prediction_algorithms/algo_base.py:248: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Done computing similarity matrix.
# RMSE: 1.4203
# 1.4203341765796793

# %%
df_result = pd.DataFrame(predictions)
df_result
# Out:
#                         uid                                        iid  r_ui  \
# 0                kelsyf2016  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 1           TandCAdventures                              Exploratorium   0.0
# 2              traveler1327                            Legion_of_Honor   0.0
# 3                  anarayan             California_Academy_of_Sciences   0.0
# 4                     CLT29                         Ghirardelli_Square   0.0
# 5                 Alok_Bahl                              Exploratorium   5.0
# 6              thakersuresh                              Exploratorium   0.0
# 7          Whatsinaname7172             San_Francisco_Botanical_Garden   0.0
# 8                LiannaS539                         Ghirardelli_Square   0.0
# 9                   Pickids                                 Twin_Peaks   0.0
# 10                  micchio                Palace_of_Fine_Arts_Theatre   0.0
# 11           williewonker65             California_Academy_of_Sciences   0.0
# 12           samuelmckinzie                Palace_of_Fine_Arts_Theatre   0.0
# 13               MannyG2000                      16_Avenue_Tiled_Steps   0.0
# 14          SallyCalifornia                              Exploratorium   0.0
# 15               Mohit_Wad1                          Fisherman_s_Wharf   0.0
# 16               Gooner10-8                             Lombard_Street   0.0
# 17           nathandX5968YJ                     or5-Golden_Gate_Bridge   0.0
# 18              ninasche117             San_Francisco_Botanical_Garden   0.0
# 19                D_W_10017                           Cable_Car_Museum   0.0
# 20           Traceycullen15                Palace_of_Fine_Arts_Theatre   0.0
# 21             jammyjameela                       Mission_Dolores_Park   3.0
# 22                   lotanp                     or5-Golden_Gate_Bridge   5.0
# 23                    CANJG                                Baker_Beach   0.0
# 24                Chelsea42  San_Francisco_Museum_of_Modern_Art_SFMOMA   5.0
# 25            Travellerpics                                 Coit_Tower   0.0
# 26                936briank                                 Twin_Peaks   0.0
# 27             paulmH5689YV             San_Francisco_Botanical_Garden   0.0
# 28               makeitso4u                             Lombard_Street   4.0
# 29            Culture467512                                 Coit_Tower   0.0
# ...                     ...                                        ...   ...
# 40209              LAPBhona                           Golden_Gate_Park   0.0
# 40210          johnsJ8383VA                    Angel_Island_State_Park   0.0
# 40211        stevengU3104CH                                 Coit_Tower   0.0
# 40212        Michelelabelle                                 Cable_Cars   0.0
# 40213                toga1k                           Cable_Car_Museum   0.0
# 40214               Kalmusc                    Angel_Island_State_Park   0.0
# 40215           carlabqtpie                                Baker_Beach   0.0
# 40216           373mauricew                         Ghirardelli_Square   4.0
# 40217                jmdfaf                       Mission_Dolores_Park   0.0
# 40218  TravellingBoneDoctor                                 Cable_Cars   4.0
# 40219       anacarolinaf467                                  Lands_End   0.0
# 40220        wantsadventure                              Exploratorium   5.0
# 40221        GunterHeimlich  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 40222              891amana             California_Academy_of_Sciences   0.0
# 40223          fernandowr10  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 40224             191semiha                                    Pier_39   0.0
# 40225             memmottrw                    Angel_Island_State_Park   0.0
# 40226                KH_RWC                      16_Avenue_Tiled_Steps   0.0
# 40227         Luv2hikejulie                    Angel_Island_State_Park   0.0
# 40228            Crimitorii             California_Academy_of_Sciences   0.0
# 40229       minimuffinlover                      16_Avenue_Tiled_Steps   0.0
# 40230        alisonmE9508KX                            Alcatraz_Island   0.0
# 40231         rosalines2017                                  Lands_End   0.0
# 40232               KinSeng                                  Lands_End   0.0
# 40233           williamr896                 Ferry_Building_Marketplace   0.0
# 40234              AndyC655                              Exploratorium   0.0
# 40235                 Tex88                               Union_Square   0.0
# 40236              Kelsie05                         Ghirardelli_Square   0.0
# 40237             Memsochet                       Mission_Dolores_Park   0.0
# 40238               vinaboe                  Walt_Disney_Family_Museum   4.0
#
#             est                                    details
# 0      0.000000   {'actual_k': 8, 'was_impossible': False}
# 1      0.582080  {'actual_k': 24, 'was_impossible': False}
# 2      0.724931  {'actual_k': 40, 'was_impossible': False}
# 3      0.931495  {'actual_k': 16, 'was_impossible': False}
# 4      0.625144  {'actual_k': 34, 'was_impossible': False}
# 5      0.435653   {'actual_k': 8, 'was_impossible': False}
# 6      0.091051  {'actual_k': 16, 'was_impossible': False}
# 7      0.000000  {'actual_k': 35, 'was_impossible': False}
# 8      0.967402  {'actual_k': 40, 'was_impossible': False}
# 9      0.618845  {'actual_k': 39, 'was_impossible': False}
# 10     1.195209  {'actual_k': 26, 'was_impossible': False}
# 11     0.934744  {'actual_k': 37, 'was_impossible': False}
# 12     0.792547  {'actual_k': 21, 'was_impossible': False}
# 13     0.559691  {'actual_k': 20, 'was_impossible': False}
# 14     0.377088  {'actual_k': 40, 'was_impossible': False}
# 15     1.473067  {'actual_k': 39, 'was_impossible': False}
# 16     1.858672  {'actual_k': 40, 'was_impossible': False}
# 17     0.393396  {'actual_k': 28, 'was_impossible': False}
# 18     0.410538  {'actual_k': 37, 'was_impossible': False}
# 19     0.465253  {'actual_k': 38, 'was_impossible': False}
# 20     0.119814  {'actual_k': 22, 'was_impossible': False}
# 21     0.000000   {'actual_k': 7, 'was_impossible': False}
# 22     0.117878  {'actual_k': 40, 'was_impossible': False}
# 23     0.129559  {'actual_k': 31, 'was_impossible': False}
# 24     0.669245   {'actual_k': 7, 'was_impossible': False}
# 25     0.263437  {'actual_k': 39, 'was_impossible': False}
# 26     1.229739  {'actual_k': 37, 'was_impossible': False}
# 27     0.112575  {'actual_k': 36, 'was_impossible': False}
# 28     1.999701  {'actual_k': 39, 'was_impossible': False}
# 29     0.970556  {'actual_k': 21, 'was_impossible': False}
# ...         ...                                        ...
# 40209  1.104483  {'actual_k': 40, 'was_impossible': False}
# 40210  0.606429  {'actual_k': 10, 'was_impossible': False}
# 40211  1.576587  {'actual_k': 17, 'was_impossible': False}
# 40212  0.306513  {'actual_k': 30, 'was_impossible': False}
# 40213  0.530048  {'actual_k': 38, 'was_impossible': False}
# 40214  0.000000   {'actual_k': 9, 'was_impossible': False}
# 40215  0.619574  {'actual_k': 37, 'was_impossible': False}
# 40216  0.138349  {'actual_k': 36, 'was_impossible': False}
# 40217  0.000000  {'actual_k': 38, 'was_impossible': False}
# 40218  2.428571  {'actual_k': 35, 'was_impossible': False}
# 40219  0.197075  {'actual_k': 27, 'was_impossible': False}
# 40220  1.065450  {'actual_k': 30, 'was_impossible': False}
# 40221  0.450322   {'actual_k': 9, 'was_impossible': False}
# 40222  1.299593  {'actual_k': 30, 'was_impossible': False}
# 40223  0.939129   {'actual_k': 5, 'was_impossible': False}
# 40224  0.300905  {'actual_k': 37, 'was_impossible': False}
# 40225  0.558186  {'actual_k': 37, 'was_impossible': False}
# 40226  0.275818  {'actual_k': 21, 'was_impossible': False}
# 40227  0.409271  {'actual_k': 25, 'was_impossible': False}
# 40228  1.122559  {'actual_k': 36, 'was_impossible': False}
# 40229  0.377677  {'actual_k': 39, 'was_impossible': False}
# 40230  0.000000  {'actual_k': 34, 'was_impossible': False}
# 40231  0.000000  {'actual_k': 14, 'was_impossible': False}
# 40232  0.441990  {'actual_k': 32, 'was_impossible': False}
# 40233  0.475355  {'actual_k': 37, 'was_impossible': False}
# 40234  0.091239  {'actual_k': 40, 'was_impossible': False}
# 40235  0.242681  {'actual_k': 29, 'was_impossible': False}
# 40236  1.288938   {'actual_k': 9, 'was_impossible': False}
# 40237  0.000000  {'actual_k': 16, 'was_impossible': False}
# 40238  0.640861  {'actual_k': 33, 'was_impossible': False}
#
# [40239 rows x 5 columns]

# %%
#Check estimates for certain user
df_result[df_result["uid"] == "834tamih"]
# Out:
#             uid                             iid  r_ui       est  \
# 3668   834tamih           16_Avenue_Tiled_Steps   0.0  0.674253
# 8827   834tamih                 Legion_of_Honor   0.0  0.000000
# 9764   834tamih               Fisherman_s_Wharf   0.0  0.050817
# 10500  834tamih     Palace_of_Fine_Arts_Theatre   0.0  0.000000
# 12277  834tamih                 De_Young_Museum   0.0  0.938937
# 15972  834tamih       Presidio_of_San_Francisco   5.0  2.184342
# 16222  834tamih                      Twin_Peaks   0.0  1.037484
# 17659  834tamih                  Haight_Ashbury   0.0  0.974513
# 26234  834tamih                     Oracle_Park   0.0  0.000000
# 29313  834tamih                       Lands_End   0.0  4.500000
# 29998  834tamih                 Alcatraz_Island   0.0  0.078566
# 33488  834tamih                Golden_Gate_Park   0.0  1.057313
# 34978  834tamih                      Cable_Cars   0.0  0.050157
# 38689  834tamih  San_Francisco_Botanical_Garden   4.0  0.531329
#
#                                          details
# 3668   {'actual_k': 19, 'was_impossible': False}
# 8827    {'actual_k': 2, 'was_impossible': False}
# 9764   {'actual_k': 35, 'was_impossible': False}
# 10500   {'actual_k': 2, 'was_impossible': False}
# 12277  {'actual_k': 21, 'was_impossible': False}
# 15972  {'actual_k': 21, 'was_impossible': False}
# 16222  {'actual_k': 22, 'was_impossible': False}
# 17659  {'actual_k': 10, 'was_impossible': False}
# 26234   {'actual_k': 7, 'was_impossible': False}
# 29313   {'actual_k': 2, 'was_impossible': False}
# 29998  {'actual_k': 25, 'was_impossible': False}
# 33488  {'actual_k': 21, 'was_impossible': False}
# 34978  {'actual_k': 24, 'was_impossible': False}
# 38689  {'actual_k': 25, 'was_impossible': False}

# %%
#Check highest estimates
df_result.sort_values(by=['est'],ascending=False)
# Out:
#                       uid                                        iid  r_ui  \
# 21560            ConnorYM                                  Lands_End   0.0
# 5958               K393YT                           Golden_Gate_Park   0.0
# 23012            BethB246                     or5-Golden_Gate_Bridge   0.0
# 24259           AzraelMel                           Golden_Gate_Park   0.0
# 29313            834tamih                                  Lands_End   0.0
# 18287        537beverleyg                     or5-Golden_Gate_Bridge   0.0
# 9495             Laurie48                                  Lands_End   5.0
# 4819     Adelaide_girl_SA                Palace_of_Fine_Arts_Theatre   5.0
# 12086    Seasondtraveller                            De_Young_Museum   5.0
# 560            joanneb648                     or5-Golden_Gate_Bridge   4.0
# 21086  WednesdayNightGirl                                 Cable_Cars   0.0
# 4425           raindrop26                            De_Young_Museum   5.0
# 15289           37doulton                     or5-Golden_Gate_Bridge   5.0
# 39835           Hison1961                     or5-Golden_Gate_Bridge   0.0
# 25104           Trish1781                     or5-Golden_Gate_Bridge   3.0
# 8000              esamlen                            De_Young_Museum   1.0
# 23339               beim4                     or5-Golden_Gate_Bridge   4.0
# 13933             Fazzers                     or5-Golden_Gate_Bridge   5.0
# 26270          885jeannea                     or5-Golden_Gate_Bridge   0.0
# 3093            128mariep                     or5-Golden_Gate_Bridge   5.0
# 24004     Modestotrekkerl                            Legion_of_Honor   5.0
# 7116   ClermontTravel1945                     or5-Golden_Gate_Bridge   0.0
# 36980              rdpine                     or5-Golden_Gate_Bridge   5.0
# 12797          stonerose5                                 Cable_Cars   0.0
# 11803       chrisfJ3717RU                     or5-Golden_Gate_Bridge   4.0
# 38938              pkcush             California_Academy_of_Sciences   5.0
# 1351            tonytt_11                     or5-Golden_Gate_Bridge   0.0
# 37583           beckyc447                     or5-Golden_Gate_Bridge   3.0
# 16746          Sam_geddes                     or5-Golden_Gate_Bridge   4.0
# 27753        steven010203                     or5-Golden_Gate_Bridge   5.0
# ...                   ...                                        ...   ...
# 12340           45Frank10                    Angel_Island_State_Park   0.0
# 31111    markthesharkOhio                 or1395-Museum_of_Ice_Cream   0.0
# 31145             tinkati                            De_Young_Museum   0.0
# 12331     stephenbW6996VK                  Walt_Disney_Family_Museum   0.0
# 12326        AKcabingirlA                       Mission_Dolores_Park   0.0
# 31151             Pakiana                            Alcatraz_Island   0.0
# 12322           helens353  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 12319          605martynh                            Legion_of_Honor   0.0
# 12318               SS450                Palace_of_Fine_Arts_Theatre   0.0
# 12370        Invisibl3Kid                      16_Avenue_Tiled_Steps   0.0
# 31109              SeanJ5                  Walt_Disney_Family_Museum   0.0
# 31052             SAB5859                           Cable_Car_Museum   0.0
# 31067         glendale215                             Haight_Ashbury   0.0
# 12443              Bunty8             San_Francisco_Botanical_Garden   0.0
# 12440           Laura99IN                    Angel_Island_State_Park   0.0
# 12439            Diane640                                  Lands_End   0.0
# 31059            Yanzo_FG                                Baker_Beach   0.0
# 31060           836eldent                    Angel_Island_State_Park   0.0
# 12429          tksjourney                             Haight_Ashbury   0.0
# 12427          diane33405                         Ghirardelli_Square   0.0
# 12421        Rochelle1986                       Mission_Dolores_Park   0.0
# 31106      phillipdownham                    Angel_Island_State_Park   0.0
# 31070      arualgeeneebee                             Painted_Ladies   0.0
# 31073              bsu448                     or5-Golden_Gate_Bridge   0.0
# 31074           NMannersF                               Union_Square   0.0
# 12412         Richy_Bobby  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 31084         margaretcov                                Oracle_Park   0.0
# 31103              rmstrs                                Oracle_Park   0.0
# 12377             Docsalv  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
# 0              kelsyf2016  San_Francisco_Museum_of_Modern_Art_SFMOMA   0.0
#
#             est                                    details
# 21560  5.000000   {'actual_k': 1, 'was_impossible': False}
# 5958   5.000000   {'actual_k': 2, 'was_impossible': False}
# 23012  5.000000   {'actual_k': 1, 'was_impossible': False}
# 24259  5.000000   {'actual_k': 2, 'was_impossible': False}
# 29313  4.500000   {'actual_k': 2, 'was_impossible': False}
# 18287  4.042536  {'actual_k': 27, 'was_impossible': False}
# 9495   4.000000   {'actual_k': 1, 'was_impossible': False}
# 4819   4.000000   {'actual_k': 1, 'was_impossible': False}
# 12086  3.836621   {'actual_k': 4, 'was_impossible': False}
# 560    3.833333  {'actual_k': 36, 'was_impossible': False}
# 21086  3.813788   {'actual_k': 4, 'was_impossible': False}
# 4425   3.741632   {'actual_k': 4, 'was_impossible': False}
# 15289  3.726800  {'actual_k': 18, 'was_impossible': False}
# 39835  3.716991  {'actual_k': 12, 'was_impossible': False}
# 25104  3.694444  {'actual_k': 36, 'was_impossible': False}
# 8000   3.689898   {'actual_k': 4, 'was_impossible': False}
# 23339  3.610086   {'actual_k': 9, 'was_impossible': False}
# 13933  3.601801   {'actual_k': 9, 'was_impossible': False}
# 26270  3.597786  {'actual_k': 11, 'was_impossible': False}
# 3093   3.564488  {'actual_k': 40, 'was_impossible': False}
# 24004  3.559470  {'actual_k': 16, 'was_impossible': False}
# 7116   3.544567  {'actual_k': 37, 'was_impossible': False}
# 36980  3.535299   {'actual_k': 9, 'was_impossible': False}
# 12797  3.511179   {'actual_k': 4, 'was_impossible': False}
# 11803  3.509648   {'actual_k': 9, 'was_impossible': False}
# 38938  3.507437  {'actual_k': 16, 'was_impossible': False}
# 1351   3.506079   {'actual_k': 9, 'was_impossible': False}
# 37583  3.500000  {'actual_k': 34, 'was_impossible': False}
# 16746  3.498709  {'actual_k': 35, 'was_impossible': False}
# 27753  3.492888  {'actual_k': 35, 'was_impossible': False}
# ...         ...                                        ...
# 12340  0.000000  {'actual_k': 26, 'was_impossible': False}
# 31111  0.000000  {'actual_k': 33, 'was_impossible': False}
# 31145  0.000000  {'actual_k': 36, 'was_impossible': False}
# 12331  0.000000   {'actual_k': 3, 'was_impossible': False}
# 12326  0.000000  {'actual_k': 36, 'was_impossible': False}
# 31151  0.000000  {'actual_k': 30, 'was_impossible': False}
# 12322  0.000000  {'actual_k': 14, 'was_impossible': False}
# 12319  0.000000   {'actual_k': 7, 'was_impossible': False}
# 12318  0.000000  {'actual_k': 20, 'was_impossible': False}
# 12370  0.000000  {'actual_k': 38, 'was_impossible': False}
# 31109  0.000000  {'actual_k': 24, 'was_impossible': False}
# 31052  0.000000  {'actual_k': 21, 'was_impossible': False}
# 31067  0.000000  {'actual_k': 33, 'was_impossible': False}
# 12443  0.000000  {'actual_k': 36, 'was_impossible': False}
# 12440  0.000000  {'actual_k': 40, 'was_impossible': False}
# 12439  0.000000   {'actual_k': 3, 'was_impossible': False}
# 31059  0.000000  {'actual_k': 39, 'was_impossible': False}
# 31060  0.000000  {'actual_k': 39, 'was_impossible': False}
# 12429  0.000000   {'actual_k': 4, 'was_impossible': False}
# 12427  0.000000   {'actual_k': 8, 'was_impossible': False}
# 12421  0.000000  {'actual_k': 39, 'was_impossible': False}
# 31106  0.000000  {'actual_k': 27, 'was_impossible': False}
# 31070  0.000000  {'actual_k': 26, 'was_impossible': False}
# 31073  0.000000  {'actual_k': 18, 'was_impossible': False}
# 31074  0.000000  {'actual_k': 34, 'was_impossible': False}
# 12412  0.000000  {'actual_k': 10, 'was_impossible': False}
# 31084  0.000000  {'actual_k': 33, 'was_impossible': False}
# 31103  0.000000  {'actual_k': 30, 'was_impossible': False}
# 12377  0.000000   {'actual_k': 7, 'was_impossible': False}
# 0      0.000000   {'actual_k': 8, 'was_impossible': False}
#
# [40239 rows x 5 columns]

# %%
#Compile original user rating and estimated rating by model
dfresult_combined = df_new[df_new["Name"] == "834tamih"]
dfresult_combined = dfresult_combined.rename(columns={"Place": "iid"})
dfresult_combined = dfresult_combined.merge(df_result[df_result["uid"] == "834tamih"], on='iid', how='outer').drop(['uid', 'r_ui', 'details'], axis=1)
dfresult_combined
# Out:
#         Name                                        iid  Rating       est
# 0   834tamih                      16_Avenue_Tiled_Steps     0.0  0.674253
# 1   834tamih             California_Academy_of_Sciences     0.0       NaN
# 2   834tamih                            Alcatraz_Island     0.0  0.078566
# 3   834tamih                                 Cable_Cars     0.0  0.050157
# 4   834tamih                              Exploratorium     0.0       NaN
# 5   834tamih                     or5-Golden_Gate_Bridge     0.0       NaN
# 6   834tamih                           Golden_Gate_Park     0.0  1.057313
# 7   834tamih                                  Lands_End     0.0  4.500000
# 8   834tamih                                Oracle_Park     0.0  0.000000
# 9   834tamih                Palace_of_Fine_Arts_Theatre     0.0  0.000000
# 10  834tamih                                 Twin_Peaks     0.0  1.037484
# 11  834tamih                  Walt_Disney_Family_Museum     0.0       NaN
# 12  834tamih                 Ferry_Building_Marketplace     0.0       NaN
# 13  834tamih                             Lombard_Street     0.0       NaN
# 14  834tamih  San_Francisco_Museum_of_Modern_Art_SFMOMA     0.0       NaN
# 15  834tamih                                 Coit_Tower     0.0       NaN
# 16  834tamih                            Legion_of_Honor     0.0  0.000000
# 17  834tamih                          San_Francisco_Bay     0.0       NaN
# 18  834tamih                                    Pier_39     0.0       NaN
# 19  834tamih                 or1395-Museum_of_Ice_Cream     0.0       NaN
# 20  834tamih             San_Francisco_Botanical_Garden     4.0  0.531329
# 21  834tamih                            De_Young_Museum     0.0  0.938937
# 22  834tamih                           Cable_Car_Museum     0.0       NaN
# 23  834tamih                  Presidio_of_San_Francisco     5.0  2.184342
# 24  834tamih                                Baker_Beach     5.0       NaN
# 25  834tamih                    Angel_Island_State_Park     5.0       NaN
# 26  834tamih                       Mission_Dolores_Park     0.0       NaN
# 27  834tamih                          Fisherman_s_Wharf     0.0  0.050817
# 28  834tamih                        Japanese_Tea_Garden     0.0       NaN
# 29  834tamih                         Ghirardelli_Square     0.0       NaN
# 30  834tamih                                  Chinatown     0.0       NaN
# 31  834tamih                               Union_Square     0.0       NaN
# 32  834tamih                             Painted_Ladies     0.0       NaN
# 33  834tamih                             Haight_Ashbury     0.0  0.974513

# %%
predictions2 = algo.fit(trainset).test(testset)
accuracy.rmse(predictions)
